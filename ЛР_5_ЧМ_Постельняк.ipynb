# %% [markdown]
# <a href="https://colab.research.google.com/github/Dracarys38/Knute-homework/blob/main/%D0%9B%D0%A0_5_%D0%A7%D0%9C_%D0%9F%D0%BE%D1%81%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8F%D0%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Лабораторна робота 5
# Розв'язання систем нелінійних рівнянь.

# %% [markdown]
# Постельняк Ігор Сергійович ФІТ 2-15 Варіант 10

# %%
import numpy as np
import matplotlib.pyplot as plt

# Область значень для x та y
x_min, x_max = -2, 2
y_min, y_max = -3, 4
step = 0.01

# Створюємо масиви значень x та y
x, y = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

# Рівняння системи
eq1 = np.sin(x + 2) - y + 1.5
eq2 = x + np.cos(y-2) - 0.5

# Створюємо графік
fig, ax = plt.subplots(figsize=(10, 10))

# Додаємо графік першого рівняння
ax.contour(x, y, eq1, levels=[0], colors='red')

# Додаємо графік другого рівняння
ax.contour(x, y, eq2, levels=[0], colors='blue')

# Налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')

# Додаємо стрілки на кінцях осей
ax.arrow(x_min, 0, x_max - x_min, 0, head_width=0.1, head_length=0.05, fc='black', ec='black')
ax.arrow(0, y_min, 0, y_max - y_min, head_width=0.1, head_length=0.2, fc='black', ec='black')

# Додаємо сітку
plt.grid(True)

# Показуємо графік
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
from scipy import optimize

# Початкове наближення
x0, y0 = 0.5, -1.5

# Функції для простої ітерації
def f1(x):  # y = f1(x)
    return np.sin(x + 2) - 1.5

def f2(y):  # x = f2(y)
    return 0.5 - np.cos(y - 2)

# Метод простої ітерації
def iter(x, y, e):
    xn = x
    yn = y
    n = 0
    while True:
        xn1 = f2(yn)
        yn1 = f1(xn)
        n += 1
        if abs(xn1 - xn) < e and abs(yn1 - yn) < e:
            break
        xn, yn = xn1, yn1
    print('Simple iteration:')
    print('x =', round(xn1, 8), '\ny =', round(yn1, 8), '\nThe amount of iteration =', n)

iter(x0, y0, 0.0001)

# Перевірка точного розв'язку
def f3(x):  # Система рівнянь
    return np.sin(x[0] + 2) - x[1] - 1.5, x[0] + np.cos(x[1] - 2) - 0.5

sol = optimize.root(f3, [0., 0.], method='hybr')  # Перевірка розв’язку
print('Chek', sol.x)
# Out:
# Simple iteration:
# x = 1.34631804
# y = -1.70336886
# The amount of iteration = 27
# Chek [ 1.34633764 -1.70331748]

# %% [markdown]
# ![лаба 5_2.jpg](data:image/jpeg;base64,...)
